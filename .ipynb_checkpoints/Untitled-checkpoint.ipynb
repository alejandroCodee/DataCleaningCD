# %% [markdown]
# # Lectura de los datos

# %%
import pandas as pd

df = pd.read_excel('archivo_sin_duplicados.xlsx')

columnas = df.columns

df.head()
# Out:
#            Marca temporal     Fecha de Ingreso Primer Nombre Segundo Nombre  \
# 0 2017-07-03 15:31:14.890  2017-07-03 00:00:00         AXEL       FRANCISCO
# 1 2017-07-03 15:33:33.219  2017-07-03 00:00:00          YENI       YAMILETH
# 2 2017-07-03 17:42:09.427  2017-07-03 00:00:00         JOSE           ANGEL
# 3 2017-07-03 17:49:08.166  2017-07-03 00:00:00          LUIS         ALONSO
# 4 2017-07-07 10:10:51.756  2017-07-07 00:00:00      LETICIA         YOSELIN
#
#   Primer Apellido Segundo Apellido  \
# 0        ORELLANA        FERNANDEZ
# 1           PEREZ        FERNANDEZ
# 2          SANTOS           ZUNIGA
# 3          MATUTE              NaN
# 4          LOPEZ          FUENTES
#
#   Número de identidad del huésped (Separado por guiones) Lugar de procedencia  \
# 0                                    0501-1998-09900               VILLANUEVA
# 1                                    1620-1994-00463               VILLANUEVA
# 2                                    0103-1987-00280                    TOCOA
# 3                                    0209-1989-01037                    TOCOA
# 4                                    0209-1997-02856                    COLON
#
#   Aldea, barrio o colonia Teléfono celular (Separado con guión en medio)  ...  \
# 0            PUEBLO NUEVO                                      9676-8474  ...
# 1            PUEBLO NUEVO                                      9857-3268  ...
# 2            ALDEA LERIDA                                      9996-8137  ...
# 3            ALDEA LERIDA                                      9886-3116  ...
# 4      QUEBRADA DE ARENA                                       3316-9450  ...
#
#   Condición  Número de identidad del afiliado (Separado con guiones)  \
# 0  Afiliado                                    1620-1994-00463
# 1  Afiliado                                      MISMA HUESPED
# 2  Afiliado                                    0209-1989-01037
# 3  Afiliado                                      MISMO HUESPED
# 4  Afiliado                                    0209-2017-00828
#
#   Teléfono celular del afiliado (Separado con guión en medio)  \
# 0                                           98573268
# 1                                      MISMA HUESPED
# 2                                          9886-3116
# 3                                      MISMO HUESPED
# 4                                          3316-9450
#
#                     Patrono          Nombre del paciente  \
# 0              DELTA CORTES  HIJO DE YENY YAMILETH PEREZ
# 1              DELTA CORTES              HIJO DE HUESPED
# 2            COAPALMA-TOCOA               MISMO AFILIADO
# 3            COAPALMA-TOCOA                MISMO HUESPED
# 4  EXPORTADOR DEL ATLANTICO   MARIO ALBERTO MOLINA LOPEZ
#
#   Parentesco con el huésped  \
# 0                     MADRE
# 1                      HIJO
# 2                     PADRE
# 3             MISMO HUESPED
# 4                     HIJO
#
#   Teléfono celular del paciente (Separado con guión en medio)  \
# 0                                    MILSMO AFILIADO
# 1                                      MISMO HUESPED
# 2                                     MISMO AFILIADO
# 3                                      MISMO HUESPED
# 4                                     MISMO HUESPED
#
#         Causa de visita al IHSS Observaciones Unnamed: 26
# 0               Consulta médica           NaN         NaN
# 1               Consulta médica           NaN         NaN
# 2  Quimioterapia o radioterapia           NaN         NaN
# 3  Quimioterapia o radioterapia           NaN         NaN
# 4      Ingresado por enfermedad           NaN         NaN
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#           Marca temporal     Fecha de Ingreso Primer Nombre Segundo Nombre  \
# 6758 2024-04-16 16:31:26  2024-04-16 00:00:00         MIRNA        LETICIA
# 6759 2024-04-16 17:15:33  2024-04-16 00:00:00         DEYSI            NaN
# 6760 2024-04-16 17:20:33  2024-04-16 00:00:00          FLOR       DE MARIA
# 6761 2024-04-17 16:35:23  2024-04-17 00:00:00          SARA      YAQUELINE
# 6762 2024-04-18 17:19:43  2024-04-18 00:00:00         GILMA        ARACELI
#
#      Primer Apellido Segundo Apellido  \
# 6758         NAVARRO        RODRIGUEZ
# 6759         FUENTES              NaN
# 6760         FUENTES              NaN
# 6761           PONCE         MARTINEZ
# 6762           SOLIZ              NaN
#
#      Número de identidad del huésped (Separado por guiones)  \
# 6758                                    1303-1998-00139
# 6759                                    0414-1968-00031
# 6760                                    0318-2003-01013
# 6761                                    1627-1994-00423
# 6762                                    1507-1964-00015
#
#                 Lugar de procedencia Aldea, barrio o colonia  \
# 6758              CANDELARIA LEMPIRA                 CASTAÑO
# 6759             SANTA ROSA DE COPAN              LOS CEDROS
# 6760             SANTA ROSA DE COPAN              LOS CEDROS
# 6761         SANTA BARBARA LAS VEGAS               EL PLANON
# 6762  ESQUIPULAS DEL NORTE / OLANCHO            BARRIO ABAJO
#
#      Teléfono celular (Separado con guión en medio)  ... Condición  \
# 6758                                      9764-2978  ...       NaN
# 6759                                      9556-5987  ...       NaN
# 6760                                      9556-5987  ...       NaN
# 6761                                      8924-5207  ...       NaN
# 6762                                      3772-0348  ...       NaN
#
#       Número de identidad del afiliado (Separado con guiones)  \
# 6758                                                NaN
# 6759                                                NaN
# 6760                                                NaN
# 6761                                                NaN
# 6762                                                NaN
#
#      Teléfono celular del afiliado (Separado con guión en medio) Patrono  \
# 6758                                                NaN              NaN
# 6759                                                NaN              NaN
# 6760                                                NaN              NaN
# 6761                                                NaN              NaN
# 6762                                                NaN              NaN
#
#              Nombre del paciente Parentesco con el huésped  \
# 6758            BLANCA RODRIGUEZ                   HERMANA
# 6759                FLOR FUENTES                     MADRE
# 6760                FLOR FUENTES                ELLA MISMA
# 6761  GENESIS STEVEN ERAZO PONCE                      HIJO
# 6762                  ELLA MISMA                ELLA MISMA
#
#      Teléfono celular del paciente (Separado con guión en medio)  \
# 6758                                                NaN
# 6759                                                NaN
# 6760                                                NaN
# 6761                                                NaN
# 6762                                                NaN
#
#             Causa de visita al IHSS     Observaciones Unnamed: 26
# 6758                RECIENDO NACIDO    Remitida HNMCR         NaN
# 6759  Dado de alta, en recuperación               NaN         NaN
# 6760  Dado de alta, en recuperación               NaN         NaN
# 6761                Consulta Medica               NaN         NaN
# 6762                Consulta médica  CITA EN UROLOGIA         NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6763 entries, 0 to 6762
# Data columns (total 27 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Marca temporal                                               6752 non-null   datetime64[ns]
#  1   Fecha de Ingreso                                             6763 non-null   object
#  2   Primer Nombre                                                6763 non-null   object
#  3   Segundo Nombre                                               5542 non-null   object
#  4   Primer Apellido                                              6762 non-null   object
#  5   Segundo Apellido                                             5599 non-null   object
#  6   Número de identidad del huésped (Separado por guiones)       6749 non-null   object
#  7   Lugar de procedencia                                         6750 non-null   object
#  8   Aldea, barrio o colonia                                      6686 non-null   object
#  9   Teléfono celular (Separado con guión en medio)               6543 non-null   object
#  10  Sexo                                                         6763 non-null   object
#  11  Edad                                                         6763 non-null   int64
#  12  Profesión u oficio                                           6613 non-null   object
#  13  Es primera vez                                               6763 non-null   object
#  14  Cama                                                         6760 non-null   object
#  15  Iglesia                                                      6726 non-null   object
#  16  Nombre completo del afiliado                                 3308 non-null   object
#  17  Condición                                                    3244 non-null   object
#  18  Número de identidad del afiliado (Separado con guiones)      639 non-null    object
#  19  Teléfono celular del afiliado (Separado con guión en medio)  561 non-null    object
#  20  Patrono                                                      3348 non-null   object
#  21  Nombre del paciente                                          6761 non-null   object
#  22  Parentesco con el huésped                                    6739 non-null   object
#  23  Teléfono celular del paciente (Separado con guión en medio)  205 non-null    object
#  24  Causa de visita al IHSS                                      6757 non-null   object
#  25  Observaciones                                                4519 non-null   object
#  26  Unnamed: 26                                                  1 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(25)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                       Marca temporal         Edad
# count                           6752  6763.000000
# mean   2021-01-29 18:24:48.349937920    38.108088
# min       2017-07-03 15:31:14.890000     1.000000
# 25%    2019-01-22 12:41:07.363000064    26.000000
# 50%    2021-08-17 14:04:38.487500032    36.000000
# 75%    2022-12-28 15:44:48.021000192    48.000000
# max              2025-02-25 17:44:02    92.000000
# std                              NaN    14.605550

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ## Limpiando datos del afiliado (Identidad)

# %%
#Vamos a crear un diccionario para incluir todas las variaciones de "mismo huesped" 

mismos = ["M. H.", "M.H.", "MH.", "MISMA HUESPED", "MISMO HUESPED"]

# %%
def actualizar_identidad(row):
    if row['Número de identidad del afiliado (Separado con guiones)'] in mismos:
        return row['Número de identidad del huésped (Separado por guiones)']
    else:
        return row['Número de identidad del afiliado (Separado con guiones)']


df['Número de identidad del afiliado (Separado con guiones)'] = df.apply(actualizar_identidad, axis=1)

df.to_excel('CORREGIDO_modificado.xlsx', index=False)
